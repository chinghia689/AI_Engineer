# %%
import numpy as np
import tensorflow
from keras import models, preprocessing
import matplotlib.pyplot as plt
import cv2

# %%
model=models.load_model('real_fake.keras')

# %%
df=cv2.imread("/home/chinghia/AI_Engineer/Data/unnamed.jpg")

# %%
df.shape
# Out:
# (559, 1024, 3)

# %%
df=cv2.cvtColor(df,cv2.COLOR_BGR2RGB)

# %%
df=cv2.resize(df,(32,32))

# %%
df.shape
# Out:
# (32, 32, 3)

# %%
plt.imshow(df)
plt.show()

# %%
df=df.reshape(-1,32,32,3)

# %%
y_pred=model.predict(df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %%
def label_name_pred(test):
    if test > 0.5:
        return('Real')
    else:
        return('Fake')


plt.imshow(df.reshape(32,32,3))
plt.title(label_name_pred(np.argmax(y_pred)))
plt.show()

# %%
img=cv2.imread("/home/chinghia/AI_Engineer/Data/fddac74b-7798-4ac8-81af-862ae250514e.jpg")

# %%
img.shape
# Out:
# (2560, 1920, 3)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
img_pred=img.reshape(-1,32,32,3)#4d dua vao model
y_pred_re=model.predict(img_pred)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
plt.imshow(img)
plt.title(label_name_pred(np.argmax(y_pred_re)))
plt.show()
