# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import cv2

# %%
model=tf.keras.models.load_model('model.keras')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1600)           │             0 │
# ...

# %%
test=pd.read_csv('D:\DataScience\\fashion-mnist_train\\fashion-mnist_test.csv')

# %%
X=test.drop('label',axis=1)
y=test.label

# %%
X=X.values.reshape(-1,28,28,1)/255
y=keras.utils.to_categorical(y,10)

# %%
X.shape
# Out:
# (10000, 28, 28, 1)

# %%
y.shape
# Out:
# (10000, 10)

# %%
y_pred=model.predict(X)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
plt.imshow(X[50],cmap='gray')
plt.title(np.argmax(y_pred[50]))
plt.show()

# %%
img=cv2.imread('D:\DataScience\\Data\\ao-thun-dai-tay-nam-bvu1__3__0690f2ef4a27476f92ee0764719fb7ab_master.jpg')

# %%
print(img)
# Out:
# [[[232 232 232]
#   [232 232 232]
#   [232 232 232]
#   ...
#   [229 229 229]
#   [229 229 229]
#   [229 229 229]]
#
#  [[232 232 232]
#   [232 232 232]
#   [232 232 232]
#   ...
#   [229 229 229]
#   [229 229 229]
#   [229 229 229]]
#
#  [[232 232 232]
#   [232 232 232]
#   [232 232 232]
#   ...
#   [229 229 229]
#   [229 229 229]
#   [229 229 229]]
#
#  ...
#
#  [[228 232 233]
#   [228 232 233]
#   [228 232 233]
#   ...
#   [227 232 231]
#   [227 232 231]
#   [227 232 231]]
#
#  [[228 232 233]
#   [228 232 233]
#   [228 232 233]
#   ...
#   [227 232 231]
#   [227 232 231]
#   [227 232 231]]
#
#  [[228 232 233]
#   [228 232 233]
#   [228 232 233]
#   ...
#   [227 232 231]
#   [227 232 231]
#   [227 232 231]]]

# %%
img=cv2.resize(img,(28,28))

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.title('Hinh that')
plt.show()

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
img=img.reshape(-1,28,28,1)/255

# %%
img
# Out:
# array([[[[0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90588235],
#          [0.90980392],
#          [0.90588235],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
#          [0.90588235],
#          [0.90196078],
#          [0.90196078],
#          [0.90196078],
#          [0.90588235],
#          [0.90588235],
#          [0.90588235],
#          [0.90980392],
#          [0.91372549],
#          [0.90588235],
#          [0.90588235]],
#
#         [[0.90588235],
#          [0.09411765],
#          [0.44313725],
#          [0.90588235],
#          [0.90588235],
#          [0.90980392],
#          [0.91372549],
#          [0.90588235],
#          [0.90980392],
#          [0.90980392],
#          [0.90980392],
# ...

# %%
y_pred=model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
plt.imshow(img.reshape(28,28),cmap='gray')
plt.title(f'Du doan{np.argmax(y_pred)}')
plt.show()
